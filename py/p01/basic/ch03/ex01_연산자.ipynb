# %%
print("hello")
# Out:
# hello

# %%
a=10
b=3
a**b
a/3
# Out:
# 3.3333333333333335

# %%
x=3
y=x**2
y
# Out:
# 9

# %%
x=3.1
y=x**2
y
# Out:
# 9.610000000000001

# %%
x=3
y=x**2
z=[0.1, 0.01, 0.001, 0.0001, 0.00001]
for pos in z:
    temp_x = x+pos
    temp_y=temp_x**2
    print(f"x: {temp_x-x}", f"y: {temp_y-y}", f"ch: {(temp_y-y)/(temp_x-x)}")
# Out:
# x: 0.10000000000000009 y: 0.6100000000000012 ch: 6.100000000000007
# x: 0.009999999999999787 y: 0.06009999999999849 ch: 6.009999999999977
# x: 0.0009999999999998899 y: 0.006000999999999479 ch: 6.00100000000014
# x: 0.00010000000000021103 y: 0.0006000100000012054 ch: 6.000099999999392
# x: 1.0000000000065512e-05 y: 6.000009999951317e-05 ch: 6.00000999991201

# %%
print(not(10>5))
# Out:
# False

# %%
x=10
x += 1
x
# Out:
# 11

# %%
fruit = ["apple", "banana", "strawbery"]
"orange" in fruit
set(fruit)
# Out:
# {'apple', 'banana', 'strawbery'}

# %%
str(10)
# Out:
# '10'

# %%
a=10
b=20
a+b
# Out:
# 30
