# %%
fruit_tuple = ('apple', 'banana', 'orange')
print(fruit_tuple)
# Out:
# ('apple', 'banana', 'orange')

# %%
fruit_tuple[0]
# Out:
# 'apple'

# %%
fruit_tuple[0] = 'strawberry'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 fruit_tuple[0] = 'strawberry'
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = [1,2,3,4,5]
b=a

# %%
b[1] = 10
b
# Out:
# [1, 10, 3, 4, 5]

# %%
a
# Out:
# [1, 10, 3, 4, 5]

# %%
b
# Out:
# [1, 10, 3, 4, 5]

# %%
a = 10
b = a
b
# Out:
# 10

# %%
b=100
b
# Out:
# 100

# %%
a
# Out:
# 10

# %%
a, b
# Out:
# (10, 100)

# %%
def add(a, b):
    return a+b

def sub(a, b):
    return a-b

# %%
add(10,20)
# Out:
# 30

# %%
sub(10,20)
# Out:
# -10

# %%
dic = {"더하기":add, "빼기":sub, "스트링":str, "불":bool}
print(dic)
# Out:
# {'더하기': <function add at 0x0000029F6BC4CF40>, '빼기': <function sub at 0x0000029F6BC4DB20>, '스트링': <class 'str'>, '불': <class 'bool'>}

# %%
dic["더하기"](10,20)
# Out:
# 30

# %%
dic["빼기"](10,20)
# Out:
# -10

# %%
dic["스트링"].upper("abcd")
# Out:
# 'ABCD'

# %%
dic["불"](10<1)
# Out:
# False

# %%
dic["더하기"](dic["빼기"](10,20), 10)
# Out:
# 0

# %%
fruit_set = {'사과', '바나나', '오렌지'}
print(fruit_set)
# Out:
# {'사과', '오렌지', '바나나'}

# %%
for x in fruit_set:
    print(x)
# Out:
# 사과
# 오렌지
# 바나나

# %%
fruit_set = {'사과', '바나나', '오렌지', '바나나', '오렌지'}
fruit_set
# Out:
# {'바나나', '사과', '오렌지'}

# %%
print(fruit_set)
# Out:
# {'사과', '오렌지', '바나나'}

# %%
print(fruit_set)
# Out:
# {'사과', '오렌지', '바나나'}

# %%
list(fruit_set).sort()

# %%
x = list(fruit_set)
x
# Out:
# ['사과', '오렌지', '바나나']

# %%
fruit_set
# Out:
# {'바나나', '사과', '오렌지'}

# %%
x.sort()
x
# Out:
# ['바나나', '사과', '오렌지']
