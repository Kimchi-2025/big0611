# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
cat_cols = df.select_dtypes(include='category').columns

# %%
for col in cat_cols:
    print(f'{col}: {df[col].nunique()} -> {list(df[col].unique())}')
# Out:
# sex: 2 -> ['Female', 'Male']
# smoker: 2 -> ['No', 'Yes']
# day: 4 -> ['Sun', 'Sat', 'Thur', 'Fri']
# time: 2 -> ['Dinner', 'Lunch']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x=df['total_bill'], y=df['tip'], hue=df['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.heatmap(df.select_dtypes(exclude='category').corr())
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df, x='total_bill', y='tip', size='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# 다차원 시각화
# 4개 변수를 동시에 표현

sns.scatterplot(data=df, x='total_bill', y='tip', size='size', hue='sex', style='smoker', alpha=0.7)

plt.plot([0,50], [0,10], color='red')
plt.plot([0,50], [5,5])

# %%
df[['total_bill', 'tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df['tip'].hist()
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='str')

# %%
df['total_bill'].hist()
# Out:
# <Axes: >

# %%
sns.barplot(df['sex'].value_counts())
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(df['sex'])
# Out:
# <Axes: ylabel='sex'>

# %%
df['tip'].groupby('sex').mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 df['tip'].groupby('sex').mean()
#
# File c:\ajb\git\big0611\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\ajb\git\big0611\.venv\Lib\site-packages\pandas\core\series.py:2057, in Series.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#    2054 if not as_index:
#    2055     raise TypeError("as_index=False only valid with DataFrame")
# -> 2057 return SeriesGroupBy(
#    2058     obj=self,
#    2059     keys=by,
#    2060     level=level,
#    2061     as_index=as_index,
#    2062     sort=sort,
#    2063     group_keys=group_keys,
#    2064     observed=observed,
#    2065     dropna=dropna,
#    2066 )
#
# File c:\ajb\git\big0611\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File c:\ajb\git\big0611\.venv\Lib\site-packages\pandas\core\groupby\grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'sex'

# %%
plt.bar(df['sex'].value_counts().index, df['sex'].value_counts())
# Out:
# <BarContainer object of 2 artists>

# %%
sns.histplot(data=df, x='total_bill', bins=5)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.countplot(data=df, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(df['sex'].value_counts())
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=df, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>
