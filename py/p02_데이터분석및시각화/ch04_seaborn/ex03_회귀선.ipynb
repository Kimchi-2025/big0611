# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
sns.regplot(x=df['total_bill'], y=df['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(df, x='total_bill', y='tip', scatter = False)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(df, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
x= [1, 2, 3, 4, 5]
y= [10, 20, 25, 30, 42]
sns.lineplot(x=x, y=y)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['tip'].hist()
# Out:
# <Axes: >

# %%
sns.barplot(df, x='size', y='tip')
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.lineplot(df, x='size', y='tip', hue='day', errorbar=None)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
df.groupby('size')['tip'].mean()
# Out:
# size
# 1    1.437500
# 2    2.582308
# 3    3.393158
# 4    4.135405
# 5    4.028000
# 6    5.225000
# Name: tip, dtype: float64

# %%
sns.lineplot(df, x='tip', y='total_bill')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.lineplot(df, x='size', y='total_bill')
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tip.describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
temp= pd.cut(df['tip'], bins=5, labels=[1,2,3,4,5])
temp
# Out:
# 0      1
# 1      1
# 2      2
# 3      2
# 4      2
#       ..
# 239    3
# 240    1
# 241    1
# 242    1
# 243    2
# Name: tip, Length: 244, dtype: category
# Categories (5, int64): [1 < 2 < 3 < 4 < 5]

# %%
sns.lineplot(y=df['total_bill'], x=temp)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.barplot(y=df['total_bill'], x=temp, hue=df['sex'])
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.day.value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
sns.countplot(df, x ='sex', hue='time')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.groupby(['time', 'sex']).size()
# Out:
# time    sex
# Lunch   Male       33
#         Female     35
# Dinner  Male      124
#         Female     52
# dtype: int64

# %%
pd.pivot_table(df, index='sex', columns='time', aggfunc='size')
# Out:
# time    Lunch  Dinner
# sex
# Male       33     124
# Female     35      52

# %%
pd.pivot_table(
    df,
    index='time',
    columns='sex',
    aggfunc='size'
)
# Out:
# sex     Male  Female
# time
# Lunch     33      35
# Dinner   124      52

# %%
pd.crosstab(df['time'], df['sex']).plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='time'>

# %%
pd.crosstab(df['time'], df['sex']).plot(kind='bar')
# Out:
# <Axes: xlabel='time'>

# %%
pd.pivot_table(df, index='time', columns='sex', aggfunc='size')
# Out:
# sex     Male  Female
# time
# Lunch     33      35
# Dinner   124      52

# %%
sns.countplot(df, x='time', hue='sex')
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
pd.crosstab(df['time'], df['sex']).plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='time'>
